# %%
from agno.agent import Agent
from agno.models.anthropic import Claude
from dotenv import load_dotenv
import os

BASEDIR = os.path.dirname(os.path.abspath(__file__))
load_dotenv(os.path.join(BASEDIR, '.env'))

agent = Agent(
    model=Claude(
        api_key=os.getenv('ANTHROPIC_API_KEY'),
        model_name=os.getenv('ANTHROPIC_MODEL'),
        max_tokens=os.getenv('ANTHROPIC_MAX_TOKENS'),
        temperature=os.getenv('ANTHROPIC_TEMPERATURE'),
        top_p=os.getenv('ANTHROPIC_TOP_P')
    )
)

agent.print_response("Write a short poem about the sea.", stream=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       3 from dotenv import load_dotenv
#       4 import os
# ----> 6 BASEDIR = os.path.dirname(os.path.abspath(__file__))
#       7 load_dotenv(os.path.join(BASEDIR, '.env'))
#       9 agent = Agent(
#      10     model=Claude(
#      11         api_key=os.getenv('ANTHROPIC_API_KEY'),
#    (...)     16     )
#      17 )
#
# NameError: name '__file__' is not defined
